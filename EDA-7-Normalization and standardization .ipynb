# %% [markdown]
# Normalization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

# %%
file1="E:\\Naresh IT\\Sample\\Visadataset.csv"
visa=pd.read_csv(file1)
visa
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
xmin=min(visa['prevailing_wage'])

# %%
xmax=max(visa['prevailing_wage'])

# %%
dr=xmin-xmax

# %%
nr=visa['prevailing_wage']-xmin

# %%
dr=xmax-xmin

# %%
visa['prevailing_wage_new']=nr/dr

# %%
visa[['prevailing_wage','prevailing_wage_new']]
# Out:
#        prevailing_wage  prevailing_wage_new
# 0             592.2029             0.001849
# 1           83425.6500             0.261345
# 2          122996.8600             0.385312
# 3           83434.0300             0.261371
# 4          149907.3900             0.469616
# ...                ...                  ...
# 25475       77092.5700             0.241505
# 25476      279174.7900             0.874579
# 25477      146298.8500             0.458311
# 25478       86154.7700             0.269895
# 25479       70876.9100             0.222033
#
# [25480 rows x 2 columns]

# %%
file1="E:\\Naresh IT\\Sample\\Visadataset.csv"
visa=pd.read_csv(file1)

# %%
file1="E:\\Naresh IT\\Sample\\Visadataset.csv"
visa=pd.read_csv(file1)
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
visa['prevailing_wage_new']=mms.fit_transform(visa[['prevailing_wage']])

# %% [markdown]
# Standard

# %%
mean=visa['prevailing_wage'].mean()

# %%
std=visa['prevailing_wage'].std()
std
# Out:
# 52815.94232687357

# %%
nr=visa['prevailing_wage']-mean

# %%
visa['prevailing_wage_new2']=nr/std

# %%
file1="E:\\Naresh IT\\Sample\\Visadataset.csv"
visa=pd.read_csv(file1)

from sklearn.preprocessing import StandardScaler
ssn=StandardScaler()
visa['prevailing_wage_new3']=ssn.fit_transform(visa[['prevailing_wage']])

# %%
visa['prevailing_wage_new3'].max()
visa['prevailing_wage_new3'].min()
# Out:
# -1.4097095626210332

# %%
con1=visa['prevailing_wage_new3']<3
con2=visa['prevailing_wage_new3']>-3
count=len(visa[con1&con2])
count
# Out:
# 25186

# %%
import matplotlib.pyplot as plt
plt.subplot(1,2,1)
plt.hist(visa['prevailing_wage_new3'],bins=40)

plt.subplot(1,2,2)
plt.hist(visa['prevailing_wage'],bins=40)
plt.show()
