# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

# %%
file1="E:\\Naresh IT\\Sample\\Visadataset.csv"
visa=pd.read_csv(file1)
visa
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa['prevailing_wage']
# Out:
# 0           592.2029
# 1         83425.6500
# 2        122996.8600
# 3         83434.0300
# 4        149907.3900
#             ...
# 25475     77092.5700
# 25476    279174.7900
# 25477    146298.8500
# 25478     86154.7700
# 25479     70876.9100
# Name: prevailing_wage, Length: 25480, dtype: float64

# %%
visa['prevailing_wage']mean()
# Out:
# 74455.81459209183

# %%
round(visa['prevailing_wage'].mean(),2)
# Out:
# 74455.81

# %%
type(visa['prevailing_wage'])
# Out:
# pandas.core.series.Series

# %%
np.mean(visa['prevailing_wage'])
# Out:
# 74455.81459209183

# %%
visa['prevailing_wage'].median()
# Out:
# 70308.20999999999

# %%
np.median(visa['prevailing_wage'])
# Out:
# 70308.20999999999

# %%
visa['prevailing_wage'].max()
visa['prevailing_wage'].min()
visa['prevailing_wage'].std()
# Out:
# 52815.94232687357

# %%
me=round(visa['prevailing_wage'].mean())
med=round(visa['prevailing_wage'].median())
maxx=round(visa['prevailing_wage'].max())
minn=round(visa['prevailing_wage'].min())
stdd=round(visa['prevailing_wage'].std())
cou=round(visa['prevailing_wage'].count())
dict1={'mean':me,'median':med,'std':stdd,'max':maxx,'min':minn,'count':cou}

# %%
pd.DataFrame(dict1,index=['VALUES'])
# Out:
#          mean  median    std     max  min  count
# VALUES  74456   70308  52816  319210    2  25480

# %%
list1=[me,med,maxx,minn,stdd,cou]
pd.DataFrame(list1)
# Out:
#         0
# 0   74456
# 1   70308
# 2  319210
# 3       2
# 4   52816
# 5   25480

# %%
visa['prevailing_wage'].mode()
# Out:
# 0        100.66
# 1        102.70
# 2        105.96
# 3        108.12
# 4        109.06
# 5        110.51
# 6        111.11
# 7        113.60
# 8        118.43
# 9        122.65
# 10       127.89
# 11       134.15
# 12       138.76
# 13      6036.67
# 14     21894.51
# 15     24258.73
# 16     58770.05
# 17     60948.15
# 18     64357.58
# 19     74645.92
# 20     82560.28
# 21     87751.88
# 22     88664.77
# 23     93356.03
# 24    126813.75
# 25    149907.39
# Name: prevailing_wage, dtype: float64

# %%
np.mode(visa['prevailing_wage'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 np.mode(visa['prevailing_wage'])
#
# File ~\anaconda3\lib\site-packages\numpy\__init__.py:311, in __getattr__(attr)
#     308     from .testing import Tester
#     309     return Tester
# --> 311 raise AttributeError("module {!r} has no attribute "
#     312                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'mode'

# %%
visa['prevailing_wage'].nunique()
# Out:
# 25454

# %%
me=round(visa['prevailing_wage'].mean())
med=round(visa['prevailing_wage'].median())
maxx=round(visa['prevailing_wage'].max())
minn=round(visa['prevailing_wage'].min())
stdd=round(visa['prevailing_wage'].std())
cou=round(visa['prevailing_wage'].count())
dict1={'mean':me,'median':med,'std':stdd,'max':maxx,'min':minn,'count':cou}

# %%
visa.describe()
# Out:
#        no_of_employees   yr_of_estab  prevailing_wage
# count     25480.000000  25480.000000     25480.000000
# mean       5667.043210   1979.409929     74455.814592
# std       22877.928848     42.366929     52815.942327
# min         -26.000000   1800.000000         2.136700
# 25%        1022.000000   1976.000000     34015.480000
# 50%        2109.000000   1997.000000     70308.210000
# 75%        3504.000000   2005.000000    107735.512500
# max      602069.000000   2016.000000    319210.270000

# %%
data=visa['prevailing_wage']
round(np.percentile(data,25),2)
# Out:
# 34015.48

# %%
data=visa['prevailing_wage']
np.percentile(data,[50,75])
# Out:
# array([ 70308.21  , 107735.5125])

# %%
data=visa['prevailing_wage']
round(np.percentile(data,20.5),2)
# Out:
# 26541.06

# %%
np.quantile(data,0)
# Out:
# 2.1367

# %%
round(np.quantile(data,0.25),2)
# Out:
# 34015.48

# %%
freq,inter,n=plt.hist(data)

# %%
n
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 n
#
# NameError: name 'n' is not defined

# %%
plt.hist(data,density=True)
plt.show()

# %%
plt.hist2d()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 plt.hist2d()
#
# TypeError: hist2d() missing 2 required positional arguments: 'x' and 'y'

# %%
sn.histplot(data)
# Out:
# <Axes: xlabel='prevailing_wage', ylabel='Count'>

# %%
plt.boxplot(data,vert=False)
plt.show()

# %%
Q1=round(np.quantile(data,0.25),2)
Q2=round(np.quantile(data,0.50),2)
Q3=round(np.quantile(data,0.75),2)
IQR=(Q3-Q1)
LB=Q1-1.5*IQR
UB=Q3+1.5*IQR
print(Q1)
print(Q2)
print(Q3)
print(IQR)
print(LB)
print(UB)
# Out:
# 34015.48
# 70308.21
# 107735.51
# 73720.03
# -76564.565
# 218315.555

# %%
c1=data<LB
c2=data>UB
pot=visa[c1|c2]

# %%
plt.hist(pot11)
# Out:
# (array([[2.5480e+04, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#         [2.5480e+04, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#         [2.5480e+04, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#         [2.5480e+04, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#         [2.5480e+04, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#         [2.4970e+04, 3.4100e+02, 9.3000e+01, 1.9000e+01, 2.2000e+01,
#          1.0000e+01, 1.3000e+01, 5.0000e+00, 2.0000e+00, 5.0000e+00],
#         [2.5480e+04, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
# ...

# %%
c11=data>LB
c21=data<UB
pot11=visa[c11|c21]

# %%
len(pot11['prevailing_wage'])
# Out:
# 25480

# %%
c21['prevailing_wage']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 c21['prevailing_wage']
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:981, in Series.__getitem__(self, key)
#     978     return self._values[key]
#     980 elif key_is_scalar:
# --> 981     return self._get_value(key)
#     983 if is_hashable(key):
#     984     # Otherwise index.get_value will raise InvalidIndexError
#     985     try:
#     986         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:1089, in Series._get_value(self, label, takeable)
#    1086     return self._values[label]
#    1088 # Similar to Index.get_value, but we do not fall back to positional
# -> 1089 loc = self.index.get_loc(label)
#    1090 return self.index._get_values_for_loc(self, loc, label)
#
# ...
