# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

# %%
file1="E:\\Naresh IT\\Sample\\Visadataset.csv"
visa=pd.read_csv(file1)

# %%
a1=dict(visa.dtypes)
num11=[]
cat11=[]
for key,values in a1.items():
    if values=='O':
        cat11.append(key)
    elif values!='O':
        num11.append(key)

# %%
sam1=dict(visa.dtypes)
cat12=[]
num12=[]
for key,value in sam1.items():
    if value=='O':
        cat12.append(key)
    elif value!='object':
        num12.append(key)
        
cat12
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'region_of_employment',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %%
visa['case_status'].unique()
# Out:
# array(['Denied', 'Certified'], dtype=object)

# %%
dict1={'Denied':0,'Certified':1}

# %%
visa['case_status']=visa['case_status'].map(dict1)
visa.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position  case_status
# 0         592.2029         Hour                  Y            0
# ...

# %%
visa.shape
# Out:
# (25480, 12)

# %%
list1=[i for i in range(25480)]

# %%
visa['sampale']=list1

# %%
visa.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position  case_status
# 0         592.2029         Hour                  Y            0
# ...

# %%
visa.drop('sampale',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 visa.drop('sampale',axis=1,inplace=True)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
# ...

# %%
visa['full_time_position'].unique()
dict11={'Y':0,'N':1}

# %%
visa['full_time_position']=visa['full_time_position'].map(dict11)

# %%
visa.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position  case_status
# 0         592.2029         Hour                  Y            0
# ...

# %%
list1=['RAm','Legs','MEg']
list2=[1,2,3]

# %%
file1="E:\\Naresh IT\\Sample\\Visadataset.csv"
visa=pd.read_csv(file1)
keys=visa['case_status'].unique()
val=[i for i in range(len(keys))]
for k,l in(zip(keys,val)):
    print(dict(k,l))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 6
#       4 val=[i for i in range(len(keys))]
#       5 for k,l in(zip(keys,val)):
# ----> 6     print(dict(k,l))
#
# TypeError: dict expected at most 1 argument, got 2

# %%
file1="E:\\Naresh IT\\Sample\\Visadataset.csv"
visa=pd.read_csv(file1)
visa['case_status']=np.where(visa['case_status']=='Denied',0,1)

# %%
file1="E:\\Naresh IT\\Sample\\Visadataset.csv"
visa=pd.read_csv(file1)
visa.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
visa['education_of_employee'].unique()
# Out:
# array(['High School', "Master's", "Bachelor's", 'Doctorate'], dtype=object)

# %%
pd.get_dummies(visa['education_of_employee'])
# Out:
#        Bachelor's  Doctorate  High School  Master's
# 0               0          0            1         0
# 1               0          0            0         1
# 2               1          0            0         0
# 3               1          0            0         0
# 4               0          0            0         1
# ...           ...        ...          ...       ...
# 25475           1          0            0         0
# 25476           0          0            1         0
# 25477           0          0            0         1
# 25478           0          0            0         1
# 25479           1          0            0         0
#
# [25480 rows x 4 columns]

# %%
visa.loc[[100,200],['yr_of_estab']]
# Out:
#      yr_of_estab
# 100         2007
# 200         1979

# %%
visa.iloc[:1000,2:4]
# Out:
#     education_of_employee has_job_experience
# 0             High School                  N
# 1                Master's                  Y
# 2              Bachelor's                  N
# 3              Bachelor's                  N
# 4                Master's                  Y
# ..                    ...                ...
# 995              Master's                  N
# 996              Master's                  N
# 997            Bachelor's                  Y
# 998           High School                  Y
# 999             Doctorate                  N
#
# [1000 rows x 2 columns]

# %%
list1 = ['RAm', 'Legs', 'MEg']
list2 = [1, 2, 3, 4, 5]
dict1={list1[i]:list2[i] for i in range (len(list1))}

my_dict = dict(zip(list1, list2))

print(my_dict)
print(dict1)
# Out:
# {'RAm': 1, 'Legs': 2, 'MEg': 3}
# {'RAm': 1, 'Legs': 2, 'MEg': 3}

# %%
file1="E:\\Naresh IT\\Sample\\Visadataset.csv"
visa=pd.read_csv(file1)

# %%
visa['case_status'].unique()
# Out:
# array(['Denied', 'Certified'], dtype=object)

# %%
pd.get_dummies(visa['case_status'])
# Out:
#        Certified  Denied
# 0              0       1
# 1              1       0
# 2              0       1
# 3              0       1
# 4              1       0
# ...          ...     ...
# 25475          1       0
# 25476          1       0
# 25477          1       0
# 25478          1       0
# 25479          1       0
#
# [25480 rows x 2 columns]

# %%
df1=pd.get_dummies(visa,columns=['case_status'])

# %%
df1.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status_Certified', 'case_status_Denied'],
#       dtype='object')

# %%
len(cat11)
# Out:
# 9

# %%
cat11[1:]
# Out:
# ['continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'region_of_employment',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %%
visa['continent'].unique()
# Out:
# array(['Asia', 'Africa', 'North America', 'Europe', 'South America',
#        'Oceania'], dtype=object)

# %%
s=0
for i in cat11[1:]:
    a=visa[i].nunique()
    s+=a
    print(a)
    
s
# Out:
# 6
# 4
# 2
# 2
# 5
# 4
# 2
# 2
# 27

# %%
visa.lab

# %%
keys=visa['continent'].unique()
val=[i for i in range(len(keys))]
d={keys[i]:val[i] for i in range(len(keys))}

#visa['continent'].map(d)
# Out:
# {'Asia': 0,
#  'Africa': 1,
#  'North America': 2,
#  'Europe': 3,
#  'South America': 4,
#  'Oceania': 5}

# %%
file1="E:\\Naresh IT\\Sample\\Visadataset.csv"
visa=pd.read_csv(file1)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
visa['continent']=le.fit_transform(visa['continent'])
visa
# Out:
#          case_id  continent education_of_employee has_job_experience  \
# 0         EZYV01          1           High School                  N
# 1         EZYV02          1              Master's                  Y
# 2         EZYV03          1            Bachelor's                  N
# 3         EZYV04          1            Bachelor's                  N
# 4         EZYV05          0              Master's                  Y
# ...          ...        ...                   ...                ...
# 25475  EZYV25476          1            Bachelor's                  Y
# 25476  EZYV25477          1           High School                  Y
# 25477  EZYV25478          1              Master's                  Y
# 25478  EZYV25479          1              Master's                  Y
# 25479  EZYV25480          1            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
visa['education_123']=le.fit_transform(visa['education_of_employee'])
visa
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
le.inverse_transform(visa['continent'])
# Out:
# array(['Asia', 'Asia', 'Asia', ..., 'Asia', 'Asia', 'Asia'], dtype=object)

# %%
for i in cat11[1:]:
    visa[i]=le.fit_transform(visa[i])
visa
# Out:
#          case_id  continent  education_of_employee  has_job_experience  \
# 0         EZYV01          1                      2                   0
# 1         EZYV02          1                      3                   1
# 2         EZYV03          1                      0                   0
# 3         EZYV04          1                      0                   0
# 4         EZYV05          0                      3                   1
# ...          ...        ...                    ...                 ...
# 25475  EZYV25476          1                      0                   1
# 25476  EZYV25477          1                      2                   1
# 25477  EZYV25478          1                      3                   1
# 25478  EZYV25479          1                      3                   1
# 25479  EZYV25480          1                      0                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# ...
