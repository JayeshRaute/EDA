# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

# %%
file1="E:\\Naresh IT\\Sample\\Visadataset.csv"
visa=pd.read_csv(file1)
visa
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
round(visa['no_of_employees'].mean(),3)
# Out:
# 5667.043

# %%
round(visa['no_of_employees'].median(),3)
# Out:
# 2109.0

# %%
np.mean(visa['no_of_employees'])
# Out:
# 5667.043210361067

# %%
me=round(visa['prevailing_wage'].mean())
med=round(visa['prevailing_wage'].median())
maxx=round(visa['prevailing_wage'].max())
minn=round(visa['prevailing_wage'].min())
stdd=round(visa['prevailing_wage'].std())
cou=round(visa['prevailing_wage'].count())
dict1={'mean':me,'median':med,'std':stdd,'max':maxx,'min':minn,'count':cou}
pd.DataFrame(dict1,index=["Values"])
# Out:
#          mean  median    std     max  min  count
# Values  74456   70308  52816  319210    2  25480

# %%
a1=list(dict1.keys())
a11=list(dict1.values())
pd.DataFrame(zip(a1,a11),columns=['Methods',"Values"])
# Out:
#   Methods  Values
# 0    mean   74456
# 1  median   70308
# 2     std   52816
# 3     max  319210
# 4     min       2
# 5   count   25480

# %%
visa.describe()
# Out:
#        no_of_employees   yr_of_estab  prevailing_wage
# count     25480.000000  25480.000000     25480.000000
# mean       5667.043210   1979.409929     74455.814592
# std       22877.928848     42.366929     52815.942327
# min         -26.000000   1800.000000         2.136700
# 25%        1022.000000   1976.000000     34015.480000
# 50%        2109.000000   1997.000000     70308.210000
# 75%        3504.000000   2005.000000    107735.512500
# max      602069.000000   2016.000000    319210.270000

# %%
ub
# Out:
# 7227.0

# %%
data=visa['no_of_employees']
q1=round(np.quantile(data,0.25))
q2=round(np.quantile(data,0.50))
q3=round(np.quantile(data,0.75))
IQR=q3-q1
lb=q1-1.5*IQR
ub=q3+1.5*IQR
q1
# Out:
# 1022

# %%
cal1=data<lb
cal12=data>ub

# %%
plot=data[cal1|cal12]
plot
# Out:
# 0         14513
# 2         44444
# 12       123876
# 14        15756
# 16        76638
#           ...
# 25441     28199
# 25443     72892
# 25455     24335
# 25464     48785
# 25471     40224
# Name: no_of_employees, Length: 1556, dtype: int64

# %%
plt.hist(plot)
# Out:
# (array([1078.,  328.,   75.,   19.,   21.,   10.,   13.,    5.,    2.,
#            5.]),
#  array([  7242. ,  66724.7, 126207.4, 185690.1, 245172.8, 304655.5,
#         364138.2, 423620.9, 483103.6, 542586.3, 602069. ]),
#  <BarContainer object of 10 artists>)

# %%
pd.DataFrame(plot)
# Out:
#        no_of_employees
# 0                14513
# 2                44444
# 12              123876
# 14               15756
# 16               76638
# ...                ...
# 25441            28199
# 25443            72892
# 25455            24335
# 25464            48785
# 25471            40224
#
# [1556 rows x 1 columns]
