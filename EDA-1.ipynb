# %%
import pandas as pd
import numpy as np

# %%
file1="E:\\Naresh IT\\Sample\\Visadataset.csv"

# %%
pd.read_csv(file1)
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
pd.read_csv(file1)
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
file2="E:\\Naresh IT\\Sample\\bank.csv"
pd.read_csv(file)
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
file1="E:\\Naresh IT\\Sample\\Visadataset.csv"
visa=pd.read_csv(file1)

# %%
type(visa)
# Out:
# pandas.core.frame.DataFrame

# %%
visa.shape
# Out:
# (25480, 12)

# %%
print('number of rows are',visa.shape[0])
print('number of column are',visa.shape[1])
# Out:
# number of rows are 25480
# number of column are 12

# %%
visa.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
visa.tail()
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 25475                South         77092.57         Year                  Y
# ...

# %%
visa.take([0,1,2])
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# 1       83425.6500         Year                  Y   Certified
# 2      122996.8600         Year                  Y      Denied

# %%
visa.take([0,1,2],axis=1)
# Out:
#          case_id continent education_of_employee
# 0         EZYV01      Asia           High School
# 1         EZYV02      Asia              Master's
# 2         EZYV03      Asia            Bachelor's
# 3         EZYV04      Asia            Bachelor's
# 4         EZYV05    Africa              Master's
# ...          ...       ...                   ...
# 25475  EZYV25476      Asia            Bachelor's
# 25476  EZYV25477      Asia           High School
# 25477  EZYV25478      Asia              Master's
# 25478  EZYV25479      Asia              Master's
# 25479  EZYV25480      Asia            Bachelor's
#
# [25480 rows x 3 columns]

# %%
a1=[150,250,350]
b2=.take([0,1],axis=1)
visa.take(a1),b2
# Out:
#   Cell In[115], line 2
#     b2=.take([0,1],axis=1)
#        ^
# SyntaxError: invalid syntax

# %%
visa.iloc[1:6:,:10:2]
# Out:
#   case_id education_of_employee requires_job_training  yr_of_estab  \
# 1  EZYV02              Master's                     N         2002
# 2  EZYV03            Bachelor's                     Y         2008
# 3  EZYV04            Bachelor's                     N         1897
# 4  EZYV05              Master's                     N         2005
# 5  EZYV06              Master's                     N         2012
#
#    prevailing_wage
# 1         83425.65
# 2        122996.86
# 3         83434.03
# 4        149907.39
# 5         78252.14

# %%
visa.iloc[101:106,8:10]
list(visa)
type(visa)
# Out:
# pandas.core.frame.DataFrame

# %%
a10=list(visa)
type(a10)
a10.index('education_of_employee')
# Out:
# 2

# %%
visa.iloc[[100,200],[2]]
# Out:
#     education_of_employee
# 100              Master's
# 200             Doctorate

# %%
visa.iloc[[100,200,300],[2,5,11]]
# Out:
#     education_of_employee  no_of_employees case_status
# 100              Master's             2227   Certified
# 200             Doctorate             3282   Certified
# 300              Master's             3268   Certified

# %%
visa.loc[[100,200,300],['education_of_employee','education_of_employee','case_status']]
# Out:
#     education_of_employee education_of_employee case_status
# 100              Master's              Master's   Certified
# 200             Doctorate             Doctorate   Certified
# 300              Master's              Master's   Certified

# %%
visa.loc[[2200,1700],['prevailing_wage']]
# Out:
#       prevailing_wage
# 2200         22856.14
# 1700        177310.49

# %%
rows=[100,200,300]
col=['education_of_employee','education_of_employee','case_status']

# %%
visa.loc[rows,col]
# Out:
#     education_of_employee education_of_employee case_status
# 100              Master's              Master's   Certified
# 200             Doctorate             Doctorate   Certified
# 300              Master's              Master's   Certified

# %%
visa.columns
visa.columns1=list(visa.columns)
visa.columns1
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'no_of_employees',
#  'yr_of_estab',
#  'region_of_employment',
#  'prevailing_wage',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %%
visa.columns1.index('no_of_employees')
# Out:
# 5

# %%
type(visa.dtypes)
# Out:
# pandas.core.series.Series

# %%
sam1=dict(visa.dtypes)
sam1
# Out:
# {'case_id': dtype('O'),
#  'continent': dtype('O'),
#  'education_of_employee': dtype('O'),
#  'has_job_experience': dtype('O'),
#  'requires_job_training': dtype('O'),
#  'no_of_employees': dtype('int64'),
#  'yr_of_estab': dtype('int64'),
#  'region_of_employment': dtype('O'),
#  'prevailing_wage': dtype('float64'),
#  'unit_of_wage': dtype('O'),
#  'full_time_position': dtype('O'),
#  'case_status': dtype('O')}

# %%
sam1
cat=[]
num=[]
for key,value in sam1.items():
    if value=='O':
        cat.append(key)
    elif value!='object':
        num.append(key)
        
cat
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'region_of_employment',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %%
print(num1)
# Out:
# ['no_of_employees', 'yr_of_estab', 'prevailing_wage']

# %%
cols=dict(visa.dtypes)
cat=[]
num1=[]
for key,value in cols.items():
    print(key,value)
    if value=='object':
        cat.append(key)
    else:
        num1.append(key)
# Out:
# case_id object
# continent object
# education_of_employee object
# has_job_experience object
# requires_job_training object
# no_of_employees int64
# yr_of_estab int64
# region_of_employment object
# prevailing_wage float64
# unit_of_wage object
# full_time_position object
# case_status object

# %%
cols.items()
# Out:
# dict_items([('case_id', dtype('O')), ('continent', dtype('O')), ('education_of_employee', dtype('O')), ('has_job_experience', dtype('O')), ('requires_job_training', dtype('O')), ('no_of_employees', dtype('int64')), ('yr_of_estab', dtype('int64')), ('region_of_employment', dtype('O')), ('prevailing_wage', dtype('float64')), ('unit_of_wage', dtype('O')), ('full_time_position', dtype('O')), ('case_status', dtype('O'))])

# %%
visa.info
# Out:
# <bound method DataFrame.info of          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa.isnull()
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0        False      False                  False               False
# 1        False      False                  False               False
# 2        False      False                  False               False
# 3        False      False                  False               False
# 4        False      False                  False               False
# ...        ...        ...                    ...                 ...
# 25475    False      False                  False               False
# 25476    False      False                  False               False
# 25477    False      False                  False               False
# 25478    False      False                  False               False
# 25479    False      False                  False               False
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                      False            False        False
# ...

# %%
visa.isnull().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of        case_id  continent  education_of_employee  has_job_experience  \
# 0        False      False                  False               False
# 1        False      False                  False               False
# 2        False      False                  False               False
# 3        False      False                  False               False
# 4        False      False                  False               False
# ...        ...        ...                    ...                 ...
# 25475    False      False                  False               False
# 25476    False      False                  False               False
# 25477    False      False                  False               False
# 25478    False      False                  False               False
# 25479    False      False                  False               False
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
visa.take([0],axis=1)
# Out:
#          case_id
# 0         EZYV01
# 1         EZYV02
# 2         EZYV03
# 3         EZYV04
# 4         EZYV05
# ...          ...
# 25475  EZYV25476
# 25476  EZYV25477
# 25477  EZYV25478
# 25478  EZYV25479
# 25479  EZYV25480
#
# [25480 rows x 1 columns]

# %%
visa
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 visa
#
# NameError: name 'visa' is not defined
